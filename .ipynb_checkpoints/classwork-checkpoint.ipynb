# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df_08 = pd.read_csv('./all_alpha_08.csv')
df_18 = pd.read_csv('./all_alpha_18.csv')

# %%
df_08.head(20)
# Out:
#                Model  Displ       Cyl    Trans Drive      Fuel Sales Area  \
# 0          ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline         CA
# 1          ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline         FA
# 2          ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline         CA
# 3          ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline         FA
# 4           ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline         CA
# 5           ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline         FA
# 6           ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline         CA
# 7           ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline         CA
# 8           ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline         CA
# 9           ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline         FA
# 10          ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline         FA
# 11          ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline         FA
# ...

# %%
df_18.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA     T3B125
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA         U2
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA     T3B125
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA         U2
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 1      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 2      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 3      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 4  California LEV-III ULEV125  JHNXV02.4WH3  small car                    3
#
# ...

# %%
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
# Model                   2404 non-null object
# Displ                   2404 non-null float64
# Cyl                     2205 non-null object
# Trans                   2205 non-null object
# Drive                   2311 non-null object
# Fuel                    2404 non-null object
# Sales Area              2404 non-null object
# Stnd                    2404 non-null object
# Underhood ID            2404 non-null object
# Veh Class               2404 non-null object
# Air Pollution Score     2404 non-null object
# FE Calc Appr            2205 non-null object
# City MPG                2205 non-null object
# Hwy MPG                 2205 non-null object
# Cmb MPG                 2205 non-null object
# Unadj Cmb MPG           2205 non-null float64
# Greenhouse Gas Score    2205 non-null object
# SmartWay                2404 non-null object
# dtypes: float64(2), object(16)
# ...

# %%
df_08.shape
# Out:
# (2404, 18)

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 18 columns):
# Model                   1611 non-null object
# Displ                   1609 non-null float64
# Cyl                     1609 non-null float64
# Trans                   1611 non-null object
# Drive                   1611 non-null object
# Fuel                    1611 non-null object
# Cert Region             1611 non-null object
# Stnd                    1611 non-null object
# Stnd Description        1611 non-null object
# Underhood ID            1611 non-null object
# Veh Class               1611 non-null object
# Air Pollution Score     1611 non-null int64
# City MPG                1611 non-null object
# Hwy MPG                 1611 non-null object
# Cmb MPG                 1611 non-null object
# Greenhouse Gas Score    1611 non-null int64
# SmartWay                1611 non-null object
# Comb CO2                1611 non-null object
# ...

# %%
df_18.shape
# Out:
# (1611, 18)

# %% [markdown]
# ### Find duplicate rows

# %%
df_08.duplicated().sum()
# Out:
# 25

# %%
df_18.duplicated().sum()
# Out:
# 0

# %%
for k, v in df_08.iloc[0].items():
    print(f"{(k, v)}: {type(v)}")
# Out:
# ('Model', 'ACURA MDX'): <class 'str'>
# ('Displ', 3.7): <class 'numpy.float64'>
# ('Cyl', '(6 cyl)'): <class 'str'>
# ('Trans', 'Auto-S5'): <class 'str'>
# ('Drive', '4WD'): <class 'str'>
# ('Fuel', 'Gasoline'): <class 'str'>
# ('Sales Area', 'CA'): <class 'str'>
# ('Stnd', 'U2'): <class 'str'>
# ('Underhood ID', '8HNXT03.7PKR'): <class 'str'>
# ('Veh Class', 'SUV'): <class 'str'>
# ('Air Pollution Score', '7'): <class 'str'>
# ('FE Calc Appr', 'Drv'): <class 'str'>
# ('City MPG', '15'): <class 'str'>
# ('Hwy MPG', '20'): <class 'str'>
# ('Cmb MPG', '17'): <class 'str'>
# ('Unadj Cmb MPG', 22.0527): <class 'numpy.float64'>
# ('Greenhouse Gas Score', '4'): <class 'str'>
# ('SmartWay', 'no'): <class 'str'>

# %%
for k, v in df_18.iloc[0].items():
    print(f"{(k, v)}: {type(v)}")
# Out:
# ('Model', 'ACURA RDX'): <class 'str'>
# ('Displ', 3.5): <class 'numpy.float64'>
# ('Cyl', 6.0): <class 'numpy.float64'>
# ('Trans', 'SemiAuto-6'): <class 'str'>
# ('Drive', '2WD'): <class 'str'>
# ('Fuel', 'Gasoline'): <class 'str'>
# ('Cert Region', 'FA'): <class 'str'>
# ('Stnd', 'T3B125'): <class 'str'>
# ('Stnd Description', 'Federal Tier 3 Bin 125'): <class 'str'>
# ('Underhood ID', 'JHNXT03.5GV3'): <class 'str'>
# ('Veh Class', 'small SUV'): <class 'str'>
# ('Air Pollution Score', 3): <class 'numpy.int64'>
# ('City MPG', '20'): <class 'str'>
# ('Hwy MPG', '28'): <class 'str'>
# ('Cmb MPG', '23'): <class 'str'>
# ('Greenhouse Gas Score', 5): <class 'numpy.int64'>
# ('SmartWay', 'No'): <class 'str'>
# ('Comb CO2', '386'): <class 'str'>

# %% [markdown]
# ### Find records with missing values

# %%
# df_08.isnull().sum()
df_08[df_08.isnull().any(axis=1)]
# Out:
#                        Model  Displ  Cyl Trans Drive      Fuel Sales Area  \
# 389   CHEVROLET Express 3500    6.0  NaN   NaN   NaN  Gasoline         FC
# 390   CHEVROLET Express 3500    6.2  NaN   NaN   NaN  Gasoline         FC
# 391   CHEVROLET Express 3500    4.8  NaN   NaN   NaN  Gasoline         FA
# 392   CHEVROLET Express 3500    4.8  NaN   NaN   NaN  Gasoline         FA
# 393   CHEVROLET Express 3500    4.8  NaN   NaN   NaN  Gasoline         CA
# 394   CHEVROLET Express 3500    6.0  NaN   NaN   NaN  Gasoline         FA
# 395   CHEVROLET Express 3500    6.0  NaN   NaN   NaN  Gasoline         FA
# 396   CHEVROLET Express 3500    6.0  NaN   NaN   NaN  Gasoline         CA
# 449   CHEVROLET Silverado 25    4.8  NaN   NaN   2WD  Gasoline         FA
# 450   CHEVROLET Silverado 25    4.8  NaN   NaN   2WD  Gasoline         FA
# 451   CHEVROLET Silverado 25    4.8  NaN   NaN   4WD  Gasoline         FA
# 452   CHEVROLET Silverado 25    4.8  NaN   NaN   4WD  Gasoline         FA
# ...

# %%
df_18.query('Displ == "NaN"')
# Out:
#                  Model  Displ  Cyl   Trans Drive         Fuel Cert Region  \
# 996  KIA Soul Electric    NaN  NaN  Auto-1   2WD  Electricity          FA
# 997  KIA Soul Electric    NaN  NaN  Auto-1   2WD  Electricity          CA
#
#      Stnd      Stnd Description  Underhood ID      Veh Class  \
# 996  T3B0  Federal Tier 3 Bin 0  JKMXV00.0411  station wagon
# 997   ZEV        California ZEV  JKMXV00.0411  station wagon
#
#      Air Pollution Score City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score  \
# 996                   10      124      93     108                    10
# 997                   10      124      93     108                    10
#
#     SmartWay Comb CO2
# 996    Elite        0
# 997    Elite        0

# %% [markdown]
# ### Non-null unique values

# %%
df_08.nunique()
# Out:
# Model                   436
# Displ                    47
# Cyl                       8
# Trans                    14
# Drive                     2
# Fuel                      5
# Sales Area                3
# Stnd                     12
# Underhood ID            343
# Veh Class                 9
# Air Pollution Score      13
# FE Calc Appr              2
# City MPG                 39
# Hwy MPG                  43
# Cmb MPG                  38
# Unadj Cmb MPG           721
# Greenhouse Gas Score     20
# SmartWay                  2
# dtype: int64

# %%
df_18.nunique().sum()
# Out:
# 1217

# %%
df_08.groupby('Fuel').Fuel.count()
# Out:
# Fuel
# CNG               2
# Gasoline       2318
# diesel           11
# ethanol           1
# ethanol/gas      72
# Name: Fuel, dtype: int64

# %%
df_18.groupby('Fuel').Fuel.count()
# Out:
# Fuel
# Diesel                    38
# Electricity                2
# Ethanol/Gas               55
# Gasoline                1492
# Gasoline/Electricity      24
# Name: Fuel, dtype: int64

# %%
df_08.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area', 'Stnd',
#        'Underhood ID', 'Veh Class', 'Air Pollution Score', 'FE Calc Appr',
#        'City MPG', 'Hwy MPG', 'Cmb MPG', 'Unadj Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay'],
#       dtype='object')

# %%
df_18.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Cert Region',
#        'Stnd', 'Stnd Description', 'Underhood ID', 'Veh Class',
#        'Air Pollution Score', 'City MPG', 'Hwy MPG', 'Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay', 'Comb CO2'],
#       dtype='object')

# %%
df_08.drop(["Stnd", "Underhood ID", "FE Calc Appr", "Unadj Cmb MPG"], axis=1, inplace=True)
df_08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area    Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA          SUV
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA          SUV
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA          SUV
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA          SUV
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA  midsize car
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no
# 1                   6       15      20      17                    4       no
# 2                   7       17      22      19                    5       no
# 3                   6       17      22      19                    5       no
# 4                   7       16      24      19                    5       no

# %%
df_18.drop(["Stnd", "Stnd Description", "Underhood ID", "Comb CO2"], axis=1, inplace=True)
df_18.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region  Veh Class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA  small SUV
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  small car
#
#    Air Pollution Score City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score SmartWay
# 0                    3       20      28      23                     5       No
# 1                    3       20      28      23                     5       No
# 2                    3       19      27      22                     4       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No

# %% [markdown]
# ### Rename 'Sales Area' to 'Cert Region' in 2008 dataframe

# %%
df_08.rename(columns={"Sales Area": "Cert Region"}, inplace=True)
df_08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Cert Region  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
#
#      Veh Class Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# 0          SUV                   7       15      20      17
# 1          SUV                   6       15      20      17
# 2          SUV                   7       17      22      19
# 3          SUV                   6       17      22      19
# 4  midsize car                   7       16      24      19
#
#   Greenhouse Gas Score SmartWay
# 0                    4       no
# 1                    4       no
# 2                    5       no
# 3                    5       no
# 4                    5       no

# %%
df_08.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)
df_08.head()
# Out:
#        model  displ      cyl    trans drive      fuel cert_region  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
#
#      veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0          SUV                   7       15      20      17
# 1          SUV                   6       15      20      17
# 2          SUV                   7       17      22      19
# 3          SUV                   6       17      22      19
# 4  midsize car                   7       16      24      19
#
#   greenhouse_gas_score smartway
# 0                    4       no
# 1                    4       no
# 2                    5       no
# 3                    5       no
# 4                    5       no

# %%
df_18.rename(columns=lambda x: x.strip().lower().replace(" ", "_"), inplace=True)
df_18.head()
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA  small SUV
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 0                    3       20      28      23                     5       No
# 1                    3       20      28      23                     5       No
# 2                    3       19      27      22                     4       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No

# %% [markdown]
# ### Make sure all columns and columns labels match

# %%
df_08.columns == df_18.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
(df_08.columns == df_18.columns).all()
# Out:
# True

# %% [markdown]
# ### Save dataframes to CSV

# %%
df_08.to_csv('df_08_v1.csv', index=False)
df_18.to_csv('df_18_v1.csv', index=False)

# %% [markdown]
# #### <p>Cars driven in the U.S. are certified only through California. Knowing this, I decided to remove all records that don't have a 'CA' certification region.</p>

# %%
df_08.groupby('cert_region').cert_region.count()
# Out:
# cert_region
# CA    1084
# FA    1157
# FC     163
# Name: cert_region, dtype: int64

# %%
df_08 = df_08.query('cert_region == "CA"')
df_08.head()
# Out:
#        model  displ      cyl    trans drive      fuel cert_region  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 6   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline          CA
# 7   ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline          CA
#
#      veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0          SUV                   7       15      20      17
# 2          SUV                   7       17      22      19
# 4  midsize car                   7       16      24      19
# 6  midsize car                   7       18      26      21
# 7  midsize car                   7       17      26      20
#
#   greenhouse_gas_score smartway
# 0                    4       no
# 2                    5       no
# 4                    5       no
# 6                    6      yes
# 7                    6      yes

# %%
df_08.groupby('cert_region').cert_region.count()
# Out:
# cert_region
# CA    1084
# Name: cert_region, dtype: int64

# %%
df_18.groupby('cert_region').cert_region.count()
# Out:
# cert_region
# CA    798
# FA    813
# Name: cert_region, dtype: int64

# %%
df_18 = df_18.query('cert_region == "CA"')
df_18.head()
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  small car
# 6  ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA  small car
# 8  ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1                    3       20      28      23                     5       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No
# 6                    3       20      32      24                     5       No
# 8                    3       21      30      24                     5       No

# %%
df_08.drop(columns=['cert_region'], axis=1, inplace=True)
df_18.drop(columns=['cert_region'], axis=1, inplace=True)

# %%
df_08.head()
# Out:
#        model  displ      cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          SUV
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          SUV
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline  midsize car
# 6   ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline  midsize car
# 7   ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline  midsize car
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no
# 2                   7       17      22      19                    5       no
# 4                   7       16      24      19                    5       no
# 6                   7       18      26      21                    6      yes
# 7                   7       17      26      20                    6      yes

# %%
df_18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline  small car
# 6  ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline  small car
# 8  ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1                    3       20      28      23                     5       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No
# 6                    3       20      32      24                     5       No
# 8                    3       21      30      24                     5       No

# %% [markdown]
# ### Drop records with missing values

# %%
df_08.isnull().sum()
# Out:
# model                    0
# displ                    0
# cyl                     75
# trans                   75
# drive                   37
# fuel                     0
# veh_class                0
# air_pollution_score      0
# city_mpg                75
# hwy_mpg                 75
# cmb_mpg                 75
# greenhouse_gas_score    75
# smartway                 0
# dtype: int64

# %%
df_18.isnull().sum()
# Out:
# model                   0
# displ                   1
# cyl                     1
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
df_08.dropna(inplace=True)
df_18.dropna(inplace=True)

# %%
# df_08.isnull().sum()
df_08.isnull().sum().any()
# Out:
# False

# %%
# df_18.isnull().sum()
df_18.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ### Drop duplicate records

# %%
df_08.duplicated().sum()
# Out:
# 23

# %%
df_18.duplicated().sum()
# Out:
# 3

# %%
df_08.drop_duplicates(inplace=True)
df_18.drop_duplicates(inplace=True)

# %%
df_08.duplicated().sum()
# Out:
# 0

# %%
df_18.duplicated().sum()
# Out:
# 0

# %%
df_08.to_csv('df_08_v2.csv', index=False)
df_18.to_csv('df_18_v2.csv', index=False)

# %%
df_08.cyl.value_counts()
# Out:
# (6 cyl)     409
# (4 cyl)     283
# (8 cyl)     199
# (5 cyl)      48
# (12 cyl)     30
# (10 cyl)     14
# (2 cyl)       2
# (16 cyl)      1
# Name: cyl, dtype: int64

# %%
df_18.cyl.value_counts()
# Out:
# 4.0     365
# 6.0     246
# 8.0     153
# 3.0      18
# 12.0      9
# 5.0       2
# 16.0      1
# Name: cyl, dtype: int64

# %%
df_08.cyl = df_08.cyl.str.extract('(\d+)').astype(int)
df_08.cyl.value_counts()
# Out:
# 6     409
# 4     283
# 8     199
# 5      48
# 12     30
# 10     14
# 2       2
# 16      1
# Name: cyl, dtype: int64

# %%
df_18.cyl = df_18.cyl.astype(int)
df_18.cyl.value_counts()
# Out:
# 4     365
# 6     246
# 8     153
# 3      18
# 12      9
# 5       2
# 16      1
# Name: cyl, dtype: int64

# %% [markdown]
# ### Save latest version to CSV

# %%
df_08.to_csv('df_08_v3.csv', index=False)
df_18.to_csv('df_18_v3.csv', index=False)

# %%
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score      object
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score     object
# smartway                 object
# dtype: object

# %%
df_18.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score       int64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
df_08.query('air_pollution_score == "6/4"')
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %% [markdown]
# ### Find all records with 'slashed' values and create one record for each value

# %%
hybrid_08 = df_08[df_08['fuel'].str.contains('/')]
hybrid_08.head()
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
hybrid_18 = df_18[df_18['fuel'].str.contains('/')]
hybrid_18.head()
# Out:
#                 model  displ  cyl       trans drive                  fuel  \
# 108          BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 160          BMW 530e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 162          BMW 530e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 188          BMW 740e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 382  CHEVROLET Impala    3.6    6  SemiAuto-6   2WD           Ethanol/Gas
#
#      veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 108  small car                    3    28/66   34/78   30/71
# 160  small car                    7    27/70   31/75   29/72
# 162  small car                    7    27/66   31/68   28/67
# 188  large car                    3    25/62   29/68   27/64
# 382  large car                    5    14/18   20/28   16/22
#
#      greenhouse_gas_score smartway
# 108                    10      Yes
# 160                    10    Elite
# 162                    10    Elite
# ...

# %%
df1 = hybrid_08.copy()
df2 = hybrid_08.copy()

df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3e4ff234d252> in <module>
# ----> 1 df1 = hybrid_08.copy()
#       2 df2 = hybrid_08.copy()
#       3
#       4 df2.head()
#
# NameError: name 'hybrid_08' is not defined

# %%
columns_to_split = ["fuel", "air_pollution_score", "city_mpg", "hwy_mpg", "cmb_mpg", "greenhouse_gas_score"]

for i in columns_to_split:
    df1[i] = df1[i].apply(lambda x: x.split('/')[0])
    df2[i] = df2[i].apply(lambda x: x.split('/')[1])

# %%
df1.append(df2)
# Out:
#                    model  displ  cyl    trans drive     fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD      gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                   6       13      19      15                    7
# 1550                   4       18      25      21                    6
#
#      smartway
# 1550       no
# 1550       no

# %%
df_08.drop(hybrid_08.index, inplace=True)
df_08 = df_08.append(df1.append(df2), ignore_index=True)

# %%
df_08[df_08['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.query('model == "MERCEDES-BENZ C300"')
# Out:
#                   model  displ  cyl    trans drive     fuel  veh_class  \
# 985  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
# 986  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD      gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 985                   6       13      19      15                    7       no
# 986                   4       18      25      21                    6       no

# %%
df_18[df_18['fuel'].str.contains('/')].head()
# Out:
#                 model  displ  cyl       trans drive                  fuel  \
# 108          BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 160          BMW 530e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 162          BMW 530e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 188          BMW 740e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 382  CHEVROLET Impala    3.6    6  SemiAuto-6   2WD           Ethanol/Gas
#
#      veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 108  small car                    3    28/66   34/78   30/71
# 160  small car                    7    27/70   31/75   29/72
# 162  small car                    7    27/66   31/68   28/67
# 188  large car                    3    25/62   29/68   27/64
# 382  large car                    5    14/18   20/28   16/22
#
#      greenhouse_gas_score smartway
# 108                    10      Yes
# 160                    10    Elite
# 162                    10    Elite
# ...

# %%
df1 = hybrid_18.copy()
df2 = hybrid_18.copy()

columns_to_split=["fuel", "city_mpg", "hwy_mpg", "cmb_mpg"]

for i in columns_to_split:
    df1[i] = df1[i].apply(lambda x: x.split('/')[0])
    df2[i] = df2[i].apply(lambda x: x.split('/')[1])

# %% [markdown]
# ## Fix `*_mpg, greenhouse_gas_score and air_pollution` datatypes

# %%
df_18.drop(hybrid_18.index, inplace=True)
df_18 = df_18.append(df1.append(df2), ignore_index=True)

# %%
df_08.city_mpg = df_08.city_mpg.astype(int)
df_08.hwy_mpg = df_08.hwy_mpg.astype(int)
df_08.cmb_mpg = df_08.cmb_mpg.astype(int)

df_18.city_mpg = df_18.city_mpg.astype(int)
df_18.hwy_mpg = df_18.hwy_mpg.astype(int)
df_18.cmb_mpg = df_18.cmb_mpg.astype(int)

# %%
df_08.air_pollution_score = df_08.air_pollution_score.astype(float)
df_08.greenhouse_gas_score = df_08.greenhouse_gas_score.astype(float)
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                  int64
# hwy_mpg                   int64
# cmb_mpg                   int64
# greenhouse_gas_score    float64
# smartway                 object
# dtype: object

# %%
df_18.air_pollution_score = df_18.air_pollution_score.astype(float)
df_18.greenhouse_gas_score = df_18.greenhouse_gas_score.astype(float)
df_18.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                  int64
# hwy_mpg                   int64
# cmb_mpg                   int64
# greenhouse_gas_score    float64
# smartway                 object
# dtype: object

# %%
df_08.dtypes == df_18.dtypes
# Out:
# model                   True
# displ                   True
# cyl                     True
# trans                   True
# drive                   True
# fuel                    True
# veh_class               True
# air_pollution_score     True
# city_mpg                True
# hwy_mpg                 True
# cmb_mpg                 True
# greenhouse_gas_score    True
# smartway                True
# dtype: bool

# %%
df_08.to_csv('df_08_v4.csv', index=False)
df_18.to_csv('df_18.csv', index=False)

# %% [markdown]
# ## Plot Data

# %% [markdown]
# ### Distribution of greehouse gas scores in 2008

# %%
df_08.groupby('greenhouse_gas_score').air_pollution_score.count()
# Out:
# greenhouse_gas_score
# 0.0      25
# 1.0      16
# 2.0      64
# 3.0      82
# 4.0     114
# 5.0     166
# 6.0     279
# 7.0     163
# 8.0      66
# 9.0      10
# 10.0      2
# Name: air_pollution_score, dtype: int64

# %%
df_08.greenhouse_gas_score.hist(figsize=(10, 7))
plt.title("Distribution of Greenhouse Gas Scores in 2008")
plt.xlabel("Greenhouse Gas Score")
plt.ylabel("No. of occurences")
plt.show()

# %%
df_08.groupby('air_pollution_score').air_pollution_score.count()
# Out:
# air_pollution_score
# 4.0      1
# 6.0    501
# 7.0    398
# 9.0      7
# 9.5     80
# Name: air_pollution_score, dtype: int64

# %%
df_08.air_pollution_score.hist(figsize=(7,4))
plt.show()

# %%
df_18.groupby('greenhouse_gas_score').air_pollution_score.count()
# Out:
# greenhouse_gas_score
# 1.0      12
# 2.0      36
# 3.0     166
# 4.0     164
# 5.0     230
# 6.0     110
# 7.0      63
# 8.0      20
# 9.0       7
# 10.0     24
# Name: air_pollution_score, dtype: int64

# %%
df_18.greenhouse_gas_score.hist(figsize=(7, 4))
plt.show()

# %%
df_18.groupby('air_pollution_score').air_pollution_score.count()
# Out:
# air_pollution_score
# 1.0     90
# 3.0    393
# 5.0    196
# 6.0      7
# 7.0    146
# Name: air_pollution_score, dtype: int64

# %%
df_18.air_pollution_score.hist(figsize=(7, 4))
plt.show()

# %%
df_08.plot(kind="scatter", x="cmb_mpg", y="displ", figsize=(10, 7))
plt.title("Combined MPG based on displacement")
plt.xlabel("Combined MPG")
plt.ylabel("Displacement")
plt.show()

# %%
df_18.plot(kind="scatter", x="cmb_mpg", y="displ", figsize=(10, 7))
plt.title("Combined MPG based on displacement")
plt.xlabel("Combined MPG")
plt.ylabel("Displacement")
plt.show()

# %%
df_08.plot(kind="scatter", x="cmb_mpg", y="greenhouse_gas_score", figsize=(10, 7))
plt.title("Combined MPG based on Greenhouse Gas Score")
plt.xlabel("Combined MPG")
plt.ylabel("Greenhouse Gas Score")
plt.show()

# %%
df_18.plot(kind="scatter", x="cmb_mpg", y="greenhouse_gas_score", figsize=(10, 7))
plt.title("Combined MPG based on Greenhouse Gas Score")
plt.xlabel("Combined MPG")
plt.ylabel("Greenhouse Gas Score")
plt.show()

# %% [markdown]
# ## How many more car models use alternative fuels in 2018 as opposed to 2008?
# * ### May need to Google the answer to find out which fuel types are considered 'alternative'
